# %% [markdown]
# <a href="https://colab.research.google.com/github/emanuelmejia/course_time_series_python/blob/main/1.2-Paradigmas_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="padding:10px;background-color: #FF4D4D; color:white;font-size:28px;"><strong>Paradigmas en Python</strong></div>

# %% [markdown]
# <a style="padding:3px;color: #FF4D4D; font-size:20px;"><strong>Procedimental</strong></a>

# %% [markdown]
# - Se enfoca en qué hacer y cómo hacerlo paso a paso.
# - Ideal para scripts simples o tareas bien definidas.
# - Basado en ejecución secuencias de instrucciones y funciones.
# - Sencillo de entender y de estructurar.

# %%
# Procedimental
nombre = "Emanuel"
edad = 35
ubicacion = "México"

print("Hola mundo, soy", nombre, "tengo", edad, "años y nací en", ubicacion)
# Out:
# Hola mundo, soy Emanuel tengo 35 años y nací en México

# %% [markdown]
# <a style="padding:3px;color: #FF4D4D; font-size:20px;"><strong>Orientado a Objetos</strong></a>

# %% [markdown]
# -  Se enfoca en modelar el mundo real a través de objetos.
# -  Promueve el diseño modular y escalable.
# -  Organiza el código en clases y objetos que encapsulan datos y comportamiento.
# -  Facilita la reutilización y mantenimiento del código.

# %%
# Orientado a Objetos
class Persona:
    def __init__(self, nombre, edad, ubicacion):
        self.nombre = nombre
        self.edad = edad
        self.ubicacion = ubicacion
    def saludar(self):
        print(f"Hola mundo, soy {self.nombre} tengo {self.edad}, años y nací en {self.ubicacion}")
    def futuro(self):
        print(f"Dentro de 20 años tendré {self.edad + 20} años y seré la persona que rescata {self.ubicacion}")

Yo = Persona("Emanuel", 35, "México")

Yo.saludar()
# Out:
# Hola mundo, soy Emanuel tengo 35, años y nací en México

# %%
gaby = Persona("Gabriela", 49, "México")
carlos = Persona("Carlos", 33, "México")
cristina = Persona("Cristina", 54, "México")
gia = Persona("Gia", 39, "Tamaulipas")
ivan = Persona("Iván", 27, "Durango")
sabrina = Persona(ubicacion = "Hyrule", edad = 34, nombre = "Sabrina")

# %%
sabrina.futuro()
# Out:
# Dentro de 20 años tendré 54 años y seré la persona que rescata Hyrule

# %% [markdown]
# <a style="padding:3px;color: #FF4D4D; font-size:20px;"><strong>Funcional</strong></a>

# %% [markdown]
# - Se basa en el uso de funciones puras, sin usar variables globales.
# - Evita efectos secundarios, cambios de estado y el uso de bucles.
# - Fomenta el código más predecible y fácil de probar.
# - Facilita la programación declarativa y el trabajo con datos inmutables.

# %%
# Funcional
nombref = "Series de Tiempo"
saludarf = lambda nombref, edadf, ubicacionf: print(f"Hola mundo, soy {nombref} tengo {edadf}, años y nací en {ubicacionf}")

saludarf("Emanuel", 35, "México")
# Out:
# Hola mundo, soy Emanuel tengo 35, años y nací en México

# %%
nombref
# Out:
# 'Series de Tiempo'
