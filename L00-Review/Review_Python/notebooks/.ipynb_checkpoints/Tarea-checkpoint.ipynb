# %%
# ¿Qué le falta a esta función de terminal para correr adecuadamente?
pwd

# %%
# ¿Cuál es el tipo del siguiente objeto?
False

# %%
# Convertir el siguiente objeto en entero
False

# %%
# Convertir el siguiente objeto en cadena
False

# %%
# Utilizar constructores en los siguientes objetos para que la suma resulte 11 (ENTERO)
True + "10.0"

# %% [markdown]
# Clase 2

# %%
mus = "esternocleidomastoideo"
mus[-1:13:-1][::2]
# Out:
# 'odos'

# %% [markdown]
# ## LISTAS

# %% [markdown]
# Below, you can see how to turn a string into a list of characters.

# %%
X = list('butter')
X

# %% [markdown]
# Show how you would create a *new* list that had the letters in X, followed by the string 'y'.  Do **not** alter X.

# %% [markdown]
# Now show how you would append the character 'y' to the end of X (altering the original list).

# %% [markdown]
# Below, we create a new list `Y`.  Show how you would add the items in `Y` to the end of `X` (altering the original `X`, leaving `Y` unchanged).

# %%
Y = list('fly')

# %% [markdown]
# Calcular el número de elementos totales de la lista y el número de veces que aparece cierto caracter en específico.

# %% [markdown]
# ## TUPLAS

# %% [markdown]
# Create a tuple out of the list below. Store it in variable Y.

# %%
X = list("nyan")

# %%
# Tu código aquí

# %% [markdown]
# Use a slice to pull a tuple out of Y that contains the letters 'n', 'a', 'y' in that order.

# %%
# Tu código aquí

# %% [markdown]
# ## RANGO

# %% [markdown]
# Hacer un rango que incluya 7, 17, 27, 37, 47, 57

# %% [markdown]
# Verificar el número de elementos, la posición en que se encuentra 27, si incluye al número 67
