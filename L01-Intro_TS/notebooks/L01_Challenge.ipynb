# %% [markdown]
# <a href="https://colab.research.google.com/github/emanuelmejia/course_time_series_python/blob/main/L01-Intro_TS/notebooks/L01_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f8f85d5f-a146-40fd-b482-259e6f510a26" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f8f85d5f-a146-40fd-b482-259e6f510a26">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_full = pd.read_csv("/content/cbe.dat", sep='\t')
df_full
# Out:
#      choc   beer   elec
# 0    1451   96.3   1497
# 1    2037   84.4   1463
# 2    2477   91.2   1648
# 3    2785   81.9   1595
# 4    2994   80.5   1777
# ..    ...    ...    ...
# 391  8715  148.3  14338
# 392  8450  133.5  12867
# 393  9085  193.8  12761
# 394  8350  208.4  12449
# 395  7080  197.0  12658
#
# [396 rows x 3 columns]

# %%
df_full['Fecha'] = pd.period_range(start='1958-01', periods=len(df_full), freq='M')
df_full = df_full.set_index('Fecha')
df_full.head()
# Out:
#          choc  beer  elec
# Fecha
# 1958-01  1451  96.3  1497
# 1958-02  2037  84.4  1463
# 1958-03  2477  91.2  1648
# 1958-04  2785  81.9  1595
# 1958-05  2994  80.5  1777

# %%
# OJO!!!!!!!!!!!!!!
# Modifica el nombre de la columna por aquella que deseas analizar:

# Remplaza 'NOMBRE' por:

# 'choc' : Producción de bienes a base de chocolate (toneladas)
# 'beer' : Producción de cerveza (millones de litros)
# 'elec' : Producción de electricidad (millones de kWh)

df = df_full['NOMBRE'].to_frame()
df
# Out:
#           beer
# Fecha
# 1958-01   96.3
# 1958-02   84.4
# 1958-03   91.2
# 1958-04   81.9
# 1958-05   80.5
# ...        ...
# 1990-08  148.3
# 1990-09  133.5
# 1990-10  193.8
# 1990-11  208.4
# 1990-12  197.0
#
# [396 rows x 1 columns]
